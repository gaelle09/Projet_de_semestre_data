# %%
import requests

# URL for the API
url = "https://api.archives-ouvertes.fr/ref/domain/?wt=xml&q=level_i:%220%22"

# Make a GET request to the API
response = requests.get(url)

# Print the response content
if response.status_code == 200:
    print(response.text)
else:
    print(f"Error: {response.status_code}")
# Out:
# <?xml version="1.0" encoding="UTF-8"?>
# <response>
#
# <result name="response" numFound="13" start="0" numFoundExact="true">
#   <doc>
#     <str name="docid">1</str>
#     <str name="label_s">chim = Chimie</str></doc>
#   <doc>
#     <str name="docid">16</str>
#     <str name="label_s">info = Informatique [cs]</str></doc>
#   <doc>
#     <str name="docid">70</str>
#     <str name="label_s">math = Mathématiques [math]</str></doc>
#   <doc>
#     <str name="docid">103</str>
#     <str name="label_s">nlin = Science non linéaire [physics]</str></doc>
#   <doc>
#     <str name="docid">109</str>
#     <str name="label_s">phys = Physique [physics]</str></doc>
#   <doc>
#     <str name="docid">357</str>
#     <str name="label_s">qfin = Économie et finance quantitative [q-fin]</str></doc>
#   <doc>
#     <str name="docid">162</str>
#     <str name="label_s">scco = Sciences cognitives</str></doc>
#   <doc>
#     <str name="docid">167</str>
#     <str name="label_s">sde = Sciences de l'environnement</str></doc>
#   <doc>
#     <str name="docid">171</str>
#     <str name="label_s">sdu = Planète et Univers [physics]</str></doc>
#   <doc>
#     <str name="docid">193</str>
#     <str name="label_s">sdv = Sciences du Vivant [q-bio]</str></doc>
#   <doc>
#     <str name="docid">296</str>
#     <str name="label_s">shs = Sciences de l'Homme et Société</str></doc>
#   <doc>
#     <str name="docid">324</str>
#     <str name="label_s">spi = Sciences de l'ingénieur [physics]</str></doc>
#   <doc>
#     <str name="docid">347</str>
#     <str name="label_s">stat = Statistiques [stat]</str></doc>
# </result>
# </response>

# %% [markdown]
# ## CODE VALIDE

# %%
# Import the necessary libraries
import requests
import xml.etree.ElementTree as ET
import numpy as np

# %%
# Define all functions

# Step 1: Fetch domains with their meanings
def fetch_domains():
    url = "https://api.archives-ouvertes.fr/ref/domain/?wt=xml&q=level_i:%220%22"
    response = requests.get(url)
    
    domains = []
    if response.status_code == 200:
        root = ET.fromstring(response.content)
        
        for domain in root.findall(".//doc"):
            label = domain.find(".//str[@name='label_s']")
            if label is not None:
                domain_info = label.text.split(" = ")
                if len(domain_info) == 2:
                    domain_code, domain_meaning = domain_info
                    domains.append((domain_code, domain_meaning))
    else:
        print(f"Error fetching domains: {response.status_code}")
    return domains


#define a function to fetch data for a certain domain and a specific doc type
def fetch_data_1(domain_code, doc_type):
    base_url = "https://api.archives-ouvertes.fr/search/"
    query_params = {
        "q": f"level0_domain_s:\"{domain_code}\"",
        "fq": [
            "submittedDateY_i:[2021 TO 2024]",
            "fr_abstract_s:[\"\" TO *]",
            "docType_s:[\"\" TO *]",
            "primaryDomain_s:[\"\" TO *]",
            "language_t:\"fr\"",
            f"docType_s:\"{doc_type}\""
            "-fr_abstract_s:\"None\"",
        ],
        "fl": "docType_t,level0_domain_s,docid,title_s,fr_abstract_s",
        "rows": "2",
        "wt": "xml"
    }
    response = requests.get(base_url, params=query_params)

    print(domain_code, doc_type) 

    if response.status_code == 200:
        return response.content
    else:
        print(f"Error fetching data for domain {domain_code}: {response.status_code}")
        return None


#define a function to fetch data for a certain domain and a specific doc type and date

def fetch_data(domain_code, doc_type, date):
    base_url = "https://api.archives-ouvertes.fr/search/"
    query_params = {
        "q": f"level0_domain_s:\"{domain_code}\"",
        "fq": [
            f"submittedDateY_i:{date}",
            "fr_abstract_s:[\"\" TO *]",
            "docType_s:[\"\" TO *]",
            "primaryDomain_s:[\"\" TO *]",
            "language_t:\"fr\"",
            f"docType_s:\"{doc_type}\""
            "-fr_abstract_s:\"None\"",
        ],
        "fl": "docType_t,level0_domain_s,docid,title_s,fr_abstract_s",
        "rows": "2",
        "wt": "xml"
    }
    response = requests.get(base_url, params=query_params)

    print(domain_code, doc_type, date) 

    if response.status_code == 200:
        return response.content
    else:
        print(f"Error fetching data for domain {domain_code}: {response.status_code}")
        return None
    
    
# define a function with a list of document types to fetch data for a certain domain list and certain year list

def fetch_domain_doctype_data(domain_list, doc_types, dates):
    for i in range(len(domain_list)-1):
        for doc_type in doc_types:
            for date in dates:
                fetch_data(domain_list[i][0], doc_type, date)

# %%
# Define the list of document types
doc_types = ["THESE", "COUV", "MEM", "ART", "REPORT", "COMM", "POSTER", "OTHER", "OUV"]

# Retrieve the domains
domains = fetch_domains()

#Define the list of years
dates = np.array([2021, 2022, 2023, 2024])

# %%
fetch_data_1(domains[0][0], doc_types[0])

# %%
fetch_data(domains[0][0], doc_types[0], dates[0])

# %%
fetch_data(domains[0][0], doc_types[0], dates[1])

# %%
fetch_data(domains[0][0], doc_types[0], dates[2])

# %%
fetch_data(domains[0][0], doc_types[0], dates[3])

# %%
fetch_data(domains[0][0], doc_types[0], dates[-1])

# %% [markdown]
# ## TESTS

# %%
fetch_data_1(domains[0][0], doc_types[0])

# %%
print(len(domains))

# %%
for domain_code in domains:
    print(domain_code)

# %%
# Iterate over the domains and fetch data for each one

for i in range(len(domains)-1):
    # URL for the API
    url = "https://api.archives-ouvertes.fr/ref/domain/?wt=xml&q=level_i:%220%22"

    # Make a GET request to the API
    response = requests.get(url)
    base_url = "https://api.archives-ouvertes.fr/search/"
    query_params = {
        "q": f"level0_domain_s:\"{domains[i][0]}\"",
        "fq": [
            "submittedDateY_i:[2020 TO *]",
            "fr_abstract_s:[\"\" TO *]",
            "docType_s:[\"\" TO *]",
            "primaryDomain_s:[\"\" TO *]",
            "language_t:\"fr\""
            "-fr_abstract_s:\"None\"",
            "docType_s:(\"THESE\" OR \"COUV\" OR \"MEM\" OR \"ART\" OR \"REPORT\" OR \"COMM\" OR \"POSTER\" OR \"OTHER\" OR \"OUV\")",
        ],
        "fl": "docType_t,level0_domain_s,docid,title_s,fr_abstract_s",
        "group": "true",
        "group.field": "docType_s",
        "indent": "true",
        "wt": "xml"
        }

    response = requests.get(base_url, params=query_params)

    # Print the response content
    if response.status_code == 200:
        print(response.text)
    else:
        print(f"Error: {response.status_code}")

    print(domains[i][0])

# %%
######FAVORITE CODE PORTION FOR NOW --> GETTING WORKED ON##########

# Step 1: Fetch domains with their meanings
def fetch_domains():
    url = "https://api.archives-ouvertes.fr/ref/domain/?wt=xml&q=level_i:%220%22"
    response = requests.get(url)
    
    domains = []
    if response.status_code == 200:
        root = ET.fromstring(response.content)
        
        for domain in root.findall(".//doc"):
            label = domain.find(".//str[@name='label_s']")
            if label is not None:
                domain_info = label.text.split(" = ")
                if len(domain_info) == 2:
                    domain_code, domain_meaning = domain_info
                    domains.append((domain_code, domain_meaning))
    else:
        print(f"Error fetching domains: {response.status_code}")
    return domains

# Retrieve the domains
domains = fetch_domains()

# URL for the API
url = "https://api.archives-ouvertes.fr/ref/domain/?wt=xml&q=level_i:%220%22"

# Make a GET request to the API
response = requests.get(url)

base_url = "https://api.archives-ouvertes.fr/search/"
query_params = {
    "q": f"level0_domain_s:\"{domains[12][0]}\"",
    "fq": [
        "submittedDateY_i:[2020 TO *]",
        "fr_abstract_s:[\"\" TO *]",
        "docType_s:[\"\" TO *]",
        "primaryDomain_s:[\"\" TO *]",
        "language_t:\"fr\""
        "-fr_abstract_s:\"None\"",
        "docType_s:(\"THESE\" OR \"COUV\" OR \"MEM\" OR \"ART\" OR \"REPORT\" OR \"COMM\" OR \"POSTER\" OR \"OTHER\" OR \"OUV\")",
    ],
    "fl": "docType_t,level0_domain_s,docid,title_s,fr_abstract_s",
    "group": "true",
    "group.field": "docType_s",
    "indent": "true",
    "wt": "xml"
    }

response = requests.get(base_url, params=query_params)

# Print the response content
if response.status_code == 200:
    print(response.text)
else:
    print(f"Error: {response.status_code}")

print(domains[12][0])

# %% [markdown]
# ## SAVING AND CURLING DATA

# %%
import os
import subprocess


def fetch_data_curl(domain_code, doc_type, date):
    # Create the output directory based on year, doc type, and domain
    output_directory = f"{date}/{doc_type}/{domain_code}"
    os.makedirs(output_directory, exist_ok=True)
    output_file = f"{output_directory}/results.json"

    # Construct the API URL
    url = (
        f"https://api.archives-ouvertes.fr/search/?q=level0_domain_s:\"{domain_code}\""
        f"&fq=submittedDateY_i:{date}"
        f"&fq=docType_s:\"{doc_type}\""
        f"&fq=language_t:\"fr\""
        f"&fq=-fr_abstract_s:\"\""
        f"&fq=-fr_abstract_s:\"None\""
        f"&fq=fr_abstract_s:*"
        f"&fl=docType_t,level0_domain_s,docid,title_s,fr_abstract_s"
        f"&rows=100&wt=json"
    )

    # Curl command to fetch data and save it to the specified output file
    curl_command = f"curl -s '{url}' -o {output_file}"

    # Run the curl command
    subprocess.run(curl_command, shell=True)
    print(f"Data saved to {output_file}")

# %%
def fetch_domain_doctype_data_curl(domain_list, doc_types, dates):
    for domain_code, _ in domain_list:
        for doc_type in doc_types:
            for date in dates:
                fetch_data_curl(domain_code, doc_type, date)

# %%
fetch_domain_doctype_data_curl(domains, doc_types, dates)
# Out:
# Data saved to 2021/THESE/chim/results.json
# Data saved to 2022/THESE/chim/results.json
# Data saved to 2023/THESE/chim/results.json
# Data saved to 2024/THESE/chim/results.json
# Data saved to 2021/COUV/chim/results.json
# Data saved to 2022/COUV/chim/results.json
# Data saved to 2023/COUV/chim/results.json
# Data saved to 2024/COUV/chim/results.json
# Data saved to 2021/MEM/chim/results.json
# Data saved to 2022/MEM/chim/results.json
# Data saved to 2023/MEM/chim/results.json
# Data saved to 2024/MEM/chim/results.json
# Data saved to 2021/ART/chim/results.json
# Data saved to 2022/ART/chim/results.json
# Data saved to 2023/ART/chim/results.json
# Data saved to 2024/ART/chim/results.json
# Data saved to 2021/REPORT/chim/results.json
# Data saved to 2022/REPORT/chim/results.json
# Data saved to 2023/REPORT/chim/results.json
# Data saved to 2024/REPORT/chim/results.json
# Data saved to 2021/COMM/chim/results.json
# Data saved to 2022/COMM/chim/results.json
# Data saved to 2023/COMM/chim/results.json
# Data saved to 2024/COMM/chim/results.json
# Data saved to 2021/POSTER/chim/results.json
# Data saved to 2022/POSTER/chim/results.json
# Data saved to 2023/POSTER/chim/results.json
# Data saved to 2024/POSTER/chim/results.json
# Data saved to 2021/OTHER/chim/results.json
# Data saved to 2022/OTHER/chim/results.json
# Data saved to 2023/OTHER/chim/results.json
# Data saved to 2024/OTHER/chim/results.json
# Data saved to 2021/OUV/chim/results.json
# Data saved to 2022/OUV/chim/results.json
# Data saved to 2023/OUV/chim/results.json
# Data saved to 2024/OUV/chim/results.json
# Data saved to 2021/THESE/info/results.json
# Data saved to 2022/THESE/info/results.json
# Data saved to 2023/THESE/info/results.json
# Data saved to 2024/THESE/info/results.json
# Data saved to 2021/COUV/info/results.json
# Data saved to 2022/COUV/info/results.json
# Data saved to 2023/COUV/info/results.json
# Data saved to 2024/COUV/info/results.json
# Data saved to 2021/MEM/info/results.json
# Data saved to 2022/MEM/info/results.json
# Data saved to 2023/MEM/info/results.json
# Data saved to 2024/MEM/info/results.json
# Data saved to 2021/ART/info/results.json
# Data saved to 2022/ART/info/results.json
# Data saved to 2023/ART/info/results.json
# Data saved to 2024/ART/info/results.json
# Data saved to 2021/REPORT/info/results.json
# Data saved to 2022/REPORT/info/results.json
# Data saved to 2023/REPORT/info/results.json
# Data saved to 2024/REPORT/info/results.json
# Data saved to 2021/COMM/info/results.json
# Data saved to 2022/COMM/info/results.json
# Data saved to 2023/COMM/info/results.json
# Data saved to 2024/COMM/info/results.json
# Data saved to 2021/POSTER/info/results.json
# Data saved to 2022/POSTER/info/results.json
# Data saved to 2023/POSTER/info/results.json
# Data saved to 2024/POSTER/info/results.json
# Data saved to 2021/OTHER/info/results.json
# Data saved to 2022/OTHER/info/results.json
# Data saved to 2023/OTHER/info/results.json
# Data saved to 2024/OTHER/info/results.json
# Data saved to 2021/OUV/info/results.json
# Data saved to 2022/OUV/info/results.json
# Data saved to 2023/OUV/info/results.json
# Data saved to 2024/OUV/info/results.json
# Data saved to 2021/THESE/math/results.json
# Data saved to 2022/THESE/math/results.json
# Data saved to 2023/THESE/math/results.json
# Data saved to 2024/THESE/math/results.json
# Data saved to 2021/COUV/math/results.json
# Data saved to 2022/COUV/math/results.json
# Data saved to 2023/COUV/math/results.json
# Data saved to 2024/COUV/math/results.json
# Data saved to 2021/MEM/math/results.json
# Data saved to 2022/MEM/math/results.json
# Data saved to 2023/MEM/math/results.json
# Data saved to 2024/MEM/math/results.json
# Data saved to 2021/ART/math/results.json
# Data saved to 2022/ART/math/results.json
# Data saved to 2023/ART/math/results.json
# Data saved to 2024/ART/math/results.json
# Data saved to 2021/REPORT/math/results.json
# Data saved to 2022/REPORT/math/results.json
# Data saved to 2023/REPORT/math/results.json
# Data saved to 2024/REPORT/math/results.json
# Data saved to 2021/COMM/math/results.json
# Data saved to 2022/COMM/math/results.json
# Data saved to 2023/COMM/math/results.json
# Data saved to 2024/COMM/math/results.json
# Data saved to 2021/POSTER/math/results.json
# Data saved to 2022/POSTER/math/results.json
# Data saved to 2023/POSTER/math/results.json
# Data saved to 2024/POSTER/math/results.json
# Data saved to 2021/OTHER/math/results.json
# Data saved to 2022/OTHER/math/results.json
# Data saved to 2023/OTHER/math/results.json
# Data saved to 2024/OTHER/math/results.json
# Data saved to 2021/OUV/math/results.json
# Data saved to 2022/OUV/math/results.json
# Data saved to 2023/OUV/math/results.json
# Data saved to 2024/OUV/math/results.json
# Data saved to 2021/THESE/nlin/results.json
# Data saved to 2022/THESE/nlin/results.json
# Data saved to 2023/THESE/nlin/results.json
# Data saved to 2024/THESE/nlin/results.json
# Data saved to 2021/COUV/nlin/results.json
# Data saved to 2022/COUV/nlin/results.json
# Data saved to 2023/COUV/nlin/results.json
# Data saved to 2024/COUV/nlin/results.json
# Data saved to 2021/MEM/nlin/results.json
# Data saved to 2022/MEM/nlin/results.json
# Data saved to 2023/MEM/nlin/results.json
# Data saved to 2024/MEM/nlin/results.json
# Data saved to 2021/ART/nlin/results.json
# Data saved to 2022/ART/nlin/results.json
# Data saved to 2023/ART/nlin/results.json
# Data saved to 2024/ART/nlin/results.json
# Data saved to 2021/REPORT/nlin/results.json
# Data saved to 2022/REPORT/nlin/results.json
# Data saved to 2023/REPORT/nlin/results.json
# Data saved to 2024/REPORT/nlin/results.json
# Data saved to 2021/COMM/nlin/results.json
# Data saved to 2022/COMM/nlin/results.json
# Data saved to 2023/COMM/nlin/results.json
# Data saved to 2024/COMM/nlin/results.json
# Data saved to 2021/POSTER/nlin/results.json
# Data saved to 2022/POSTER/nlin/results.json
# Data saved to 2023/POSTER/nlin/results.json
# Data saved to 2024/POSTER/nlin/results.json
# Data saved to 2021/OTHER/nlin/results.json
# Data saved to 2022/OTHER/nlin/results.json
# Data saved to 2023/OTHER/nlin/results.json
# Data saved to 2024/OTHER/nlin/results.json
# Data saved to 2021/OUV/nlin/results.json
# Data saved to 2022/OUV/nlin/results.json
# Data saved to 2023/OUV/nlin/results.json
# Data saved to 2024/OUV/nlin/results.json
# Data saved to 2021/THESE/phys/results.json
# Data saved to 2022/THESE/phys/results.json
# Data saved to 2023/THESE/phys/results.json
# Data saved to 2024/THESE/phys/results.json
# Data saved to 2021/COUV/phys/results.json
# Data saved to 2022/COUV/phys/results.json
# Data saved to 2023/COUV/phys/results.json
# Data saved to 2024/COUV/phys/results.json
# Data saved to 2021/MEM/phys/results.json
# Data saved to 2022/MEM/phys/results.json
# Data saved to 2023/MEM/phys/results.json
# Data saved to 2024/MEM/phys/results.json
# Data saved to 2021/ART/phys/results.json
# Data saved to 2022/ART/phys/results.json
# Data saved to 2023/ART/phys/results.json
# Data saved to 2024/ART/phys/results.json
# Data saved to 2021/REPORT/phys/results.json
# Data saved to 2022/REPORT/phys/results.json
# Data saved to 2023/REPORT/phys/results.json
# Data saved to 2024/REPORT/phys/results.json
# Data saved to 2021/COMM/phys/results.json
# Data saved to 2022/COMM/phys/results.json
# Data saved to 2023/COMM/phys/results.json
# Data saved to 2024/COMM/phys/results.json
# Data saved to 2021/POSTER/phys/results.json
# Data saved to 2022/POSTER/phys/results.json
# Data saved to 2023/POSTER/phys/results.json
# Data saved to 2024/POSTER/phys/results.json
# Data saved to 2021/OTHER/phys/results.json
# Data saved to 2022/OTHER/phys/results.json
# Data saved to 2023/OTHER/phys/results.json
# Data saved to 2024/OTHER/phys/results.json
# Data saved to 2021/OUV/phys/results.json
# Data saved to 2022/OUV/phys/results.json
# Data saved to 2023/OUV/phys/results.json
# Data saved to 2024/OUV/phys/results.json
# Data saved to 2021/THESE/qfin/results.json
# Data saved to 2022/THESE/qfin/results.json
# Data saved to 2023/THESE/qfin/results.json
# Data saved to 2024/THESE/qfin/results.json
# Data saved to 2021/COUV/qfin/results.json
# Data saved to 2022/COUV/qfin/results.json
# Data saved to 2023/COUV/qfin/results.json
# Data saved to 2024/COUV/qfin/results.json
# Data saved to 2021/MEM/qfin/results.json
# Data saved to 2022/MEM/qfin/results.json
# Data saved to 2023/MEM/qfin/results.json
# Data saved to 2024/MEM/qfin/results.json
# Data saved to 2021/ART/qfin/results.json
# Data saved to 2022/ART/qfin/results.json
# Data saved to 2023/ART/qfin/results.json
# Data saved to 2024/ART/qfin/results.json
# Data saved to 2021/REPORT/qfin/results.json
# Data saved to 2022/REPORT/qfin/results.json
# Data saved to 2023/REPORT/qfin/results.json
# Data saved to 2024/REPORT/qfin/results.json
# Data saved to 2021/COMM/qfin/results.json
# Data saved to 2022/COMM/qfin/results.json
# Data saved to 2023/COMM/qfin/results.json
# Data saved to 2024/COMM/qfin/results.json
# Data saved to 2021/POSTER/qfin/results.json
# Data saved to 2022/POSTER/qfin/results.json
# Data saved to 2023/POSTER/qfin/results.json
# Data saved to 2024/POSTER/qfin/results.json
# Data saved to 2021/OTHER/qfin/results.json
# Data saved to 2022/OTHER/qfin/results.json
# Data saved to 2023/OTHER/qfin/results.json
# Data saved to 2024/OTHER/qfin/results.json
# Data saved to 2021/OUV/qfin/results.json
# Data saved to 2022/OUV/qfin/results.json
# Data saved to 2023/OUV/qfin/results.json
# Data saved to 2024/OUV/qfin/results.json
# Data saved to 2021/THESE/scco/results.json
# Data saved to 2022/THESE/scco/results.json
# Data saved to 2023/THESE/scco/results.json
# Data saved to 2024/THESE/scco/results.json
# Data saved to 2021/COUV/scco/results.json
# Data saved to 2022/COUV/scco/results.json
# Data saved to 2023/COUV/scco/results.json
# Data saved to 2024/COUV/scco/results.json
# Data saved to 2021/MEM/scco/results.json
# Data saved to 2022/MEM/scco/results.json
# Data saved to 2023/MEM/scco/results.json
# Data saved to 2024/MEM/scco/results.json
# Data saved to 2021/ART/scco/results.json
# Data saved to 2022/ART/scco/results.json
# Data saved to 2023/ART/scco/results.json
# Data saved to 2024/ART/scco/results.json
# Data saved to 2021/REPORT/scco/results.json
# Data saved to 2022/REPORT/scco/results.json
# Data saved to 2023/REPORT/scco/results.json
# Data saved to 2024/REPORT/scco/results.json
# Data saved to 2021/COMM/scco/results.json
# Data saved to 2022/COMM/scco/results.json
# Data saved to 2023/COMM/scco/results.json
# Data saved to 2024/COMM/scco/results.json
# Data saved to 2021/POSTER/scco/results.json
# Data saved to 2022/POSTER/scco/results.json
# Data saved to 2023/POSTER/scco/results.json
# Data saved to 2024/POSTER/scco/results.json
# Data saved to 2021/OTHER/scco/results.json
# Data saved to 2022/OTHER/scco/results.json
# Data saved to 2023/OTHER/scco/results.json
# Data saved to 2024/OTHER/scco/results.json
# Data saved to 2021/OUV/scco/results.json
# Data saved to 2022/OUV/scco/results.json
# Data saved to 2023/OUV/scco/results.json
# Data saved to 2024/OUV/scco/results.json
# Data saved to 2021/THESE/sde/results.json
# Data saved to 2022/THESE/sde/results.json
# Data saved to 2023/THESE/sde/results.json
# Data saved to 2024/THESE/sde/results.json
# Data saved to 2021/COUV/sde/results.json
# Data saved to 2022/COUV/sde/results.json
# Data saved to 2023/COUV/sde/results.json
# Data saved to 2024/COUV/sde/results.json
# Data saved to 2021/MEM/sde/results.json
# Data saved to 2022/MEM/sde/results.json
# Data saved to 2023/MEM/sde/results.json
# Data saved to 2024/MEM/sde/results.json
# Data saved to 2021/ART/sde/results.json
# Data saved to 2022/ART/sde/results.json
# Data saved to 2023/ART/sde/results.json
# Data saved to 2024/ART/sde/results.json
# Data saved to 2021/REPORT/sde/results.json
# Data saved to 2022/REPORT/sde/results.json
# Data saved to 2023/REPORT/sde/results.json
# Data saved to 2024/REPORT/sde/results.json
# Data saved to 2021/COMM/sde/results.json
# Data saved to 2022/COMM/sde/results.json
# Data saved to 2023/COMM/sde/results.json
# Data saved to 2024/COMM/sde/results.json
# Data saved to 2021/POSTER/sde/results.json
# Data saved to 2022/POSTER/sde/results.json
# Data saved to 2023/POSTER/sde/results.json
# Data saved to 2024/POSTER/sde/results.json
# Data saved to 2021/OTHER/sde/results.json
# Data saved to 2022/OTHER/sde/results.json
# Data saved to 2023/OTHER/sde/results.json
# Data saved to 2024/OTHER/sde/results.json
# Data saved to 2021/OUV/sde/results.json
# Data saved to 2022/OUV/sde/results.json
# Data saved to 2023/OUV/sde/results.json
# Data saved to 2024/OUV/sde/results.json
# Data saved to 2021/THESE/sdu/results.json
# Data saved to 2022/THESE/sdu/results.json
# Data saved to 2023/THESE/sdu/results.json
# Data saved to 2024/THESE/sdu/results.json
# Data saved to 2021/COUV/sdu/results.json
# Data saved to 2022/COUV/sdu/results.json
# Data saved to 2023/COUV/sdu/results.json
# Data saved to 2024/COUV/sdu/results.json
# Data saved to 2021/MEM/sdu/results.json
# Data saved to 2022/MEM/sdu/results.json
# Data saved to 2023/MEM/sdu/results.json
# Data saved to 2024/MEM/sdu/results.json
# Data saved to 2021/ART/sdu/results.json
# Data saved to 2022/ART/sdu/results.json
# Data saved to 2023/ART/sdu/results.json
# Data saved to 2024/ART/sdu/results.json
# Data saved to 2021/REPORT/sdu/results.json
# Data saved to 2022/REPORT/sdu/results.json
# Data saved to 2023/REPORT/sdu/results.json
# Data saved to 2024/REPORT/sdu/results.json
# Data saved to 2021/COMM/sdu/results.json
# Data saved to 2022/COMM/sdu/results.json
# Data saved to 2023/COMM/sdu/results.json
# Data saved to 2024/COMM/sdu/results.json
# Data saved to 2021/POSTER/sdu/results.json
# Data saved to 2022/POSTER/sdu/results.json
# Data saved to 2023/POSTER/sdu/results.json
# Data saved to 2024/POSTER/sdu/results.json
# Data saved to 2021/OTHER/sdu/results.json
# Data saved to 2022/OTHER/sdu/results.json
# Data saved to 2023/OTHER/sdu/results.json
# Data saved to 2024/OTHER/sdu/results.json
# Data saved to 2021/OUV/sdu/results.json
# Data saved to 2022/OUV/sdu/results.json
# Data saved to 2023/OUV/sdu/results.json
# Data saved to 2024/OUV/sdu/results.json
# Data saved to 2021/THESE/sdv/results.json
# Data saved to 2022/THESE/sdv/results.json
# Data saved to 2023/THESE/sdv/results.json
# Data saved to 2024/THESE/sdv/results.json
# Data saved to 2021/COUV/sdv/results.json
# Data saved to 2022/COUV/sdv/results.json
# Data saved to 2023/COUV/sdv/results.json
# Data saved to 2024/COUV/sdv/results.json
# Data saved to 2021/MEM/sdv/results.json
# Data saved to 2022/MEM/sdv/results.json
# Data saved to 2023/MEM/sdv/results.json
# Data saved to 2024/MEM/sdv/results.json
# Data saved to 2021/ART/sdv/results.json
# Data saved to 2022/ART/sdv/results.json
# Data saved to 2023/ART/sdv/results.json
# Data saved to 2024/ART/sdv/results.json
# Data saved to 2021/REPORT/sdv/results.json
# Data saved to 2022/REPORT/sdv/results.json
# Data saved to 2023/REPORT/sdv/results.json
# Data saved to 2024/REPORT/sdv/results.json
# Data saved to 2021/COMM/sdv/results.json
# Data saved to 2022/COMM/sdv/results.json
# Data saved to 2023/COMM/sdv/results.json
# Data saved to 2024/COMM/sdv/results.json
# Data saved to 2021/POSTER/sdv/results.json
# Data saved to 2022/POSTER/sdv/results.json
# Data saved to 2023/POSTER/sdv/results.json
# Data saved to 2024/POSTER/sdv/results.json
# Data saved to 2021/OTHER/sdv/results.json
# Data saved to 2022/OTHER/sdv/results.json
# Data saved to 2023/OTHER/sdv/results.json
# Data saved to 2024/OTHER/sdv/results.json
# Data saved to 2021/OUV/sdv/results.json
# Data saved to 2022/OUV/sdv/results.json
# Data saved to 2023/OUV/sdv/results.json
# Data saved to 2024/OUV/sdv/results.json
# Data saved to 2021/THESE/shs/results.json
# Data saved to 2022/THESE/shs/results.json
# Data saved to 2023/THESE/shs/results.json
# Data saved to 2024/THESE/shs/results.json
# Data saved to 2021/COUV/shs/results.json
# Data saved to 2022/COUV/shs/results.json
# Data saved to 2023/COUV/shs/results.json
# Data saved to 2024/COUV/shs/results.json
# Data saved to 2021/MEM/shs/results.json
# Data saved to 2022/MEM/shs/results.json
# Data saved to 2023/MEM/shs/results.json
# Data saved to 2024/MEM/shs/results.json
# Data saved to 2021/ART/shs/results.json
# Data saved to 2022/ART/shs/results.json
# Data saved to 2023/ART/shs/results.json
# Data saved to 2024/ART/shs/results.json
# Data saved to 2021/REPORT/shs/results.json
# Data saved to 2022/REPORT/shs/results.json
# Data saved to 2023/REPORT/shs/results.json
# Data saved to 2024/REPORT/shs/results.json
# Data saved to 2021/COMM/shs/results.json
# Data saved to 2022/COMM/shs/results.json
# Data saved to 2023/COMM/shs/results.json
# Data saved to 2024/COMM/shs/results.json
# Data saved to 2021/POSTER/shs/results.json
# Data saved to 2022/POSTER/shs/results.json
# Data saved to 2023/POSTER/shs/results.json
# Data saved to 2024/POSTER/shs/results.json
# Data saved to 2021/OTHER/shs/results.json
# Data saved to 2022/OTHER/shs/results.json
# Data saved to 2023/OTHER/shs/results.json
# Data saved to 2024/OTHER/shs/results.json
# Data saved to 2021/OUV/shs/results.json
# Data saved to 2022/OUV/shs/results.json
# Data saved to 2023/OUV/shs/results.json
# Data saved to 2024/OUV/shs/results.json
# Data saved to 2021/THESE/spi/results.json
# Data saved to 2022/THESE/spi/results.json
# Data saved to 2023/THESE/spi/results.json
# Data saved to 2024/THESE/spi/results.json
# Data saved to 2021/COUV/spi/results.json
# Data saved to 2022/COUV/spi/results.json
# Data saved to 2023/COUV/spi/results.json
# Data saved to 2024/COUV/spi/results.json
# Data saved to 2021/MEM/spi/results.json
# Data saved to 2022/MEM/spi/results.json
# Data saved to 2023/MEM/spi/results.json
# Data saved to 2024/MEM/spi/results.json
# Data saved to 2021/ART/spi/results.json
# Data saved to 2022/ART/spi/results.json
# Data saved to 2023/ART/spi/results.json
# Data saved to 2024/ART/spi/results.json
# Data saved to 2021/REPORT/spi/results.json
# Data saved to 2022/REPORT/spi/results.json
# Data saved to 2023/REPORT/spi/results.json
# Data saved to 2024/REPORT/spi/results.json
# Data saved to 2021/COMM/spi/results.json
# Data saved to 2022/COMM/spi/results.json
# Data saved to 2023/COMM/spi/results.json
# Data saved to 2024/COMM/spi/results.json
# Data saved to 2021/POSTER/spi/results.json
# Data saved to 2022/POSTER/spi/results.json
# Data saved to 2023/POSTER/spi/results.json
# Data saved to 2024/POSTER/spi/results.json
# Data saved to 2021/OTHER/spi/results.json
# Data saved to 2022/OTHER/spi/results.json
# Data saved to 2023/OTHER/spi/results.json
# Data saved to 2024/OTHER/spi/results.json
# Data saved to 2021/OUV/spi/results.json
# Data saved to 2022/OUV/spi/results.json
# Data saved to 2023/OUV/spi/results.json
# Data saved to 2024/OUV/spi/results.json
# Data saved to 2021/THESE/stat/results.json
# Data saved to 2022/THESE/stat/results.json
# Data saved to 2023/THESE/stat/results.json
# Data saved to 2024/THESE/stat/results.json
# Data saved to 2021/COUV/stat/results.json
# Data saved to 2022/COUV/stat/results.json
# Data saved to 2023/COUV/stat/results.json
# Data saved to 2024/COUV/stat/results.json
# Data saved to 2021/MEM/stat/results.json
# Data saved to 2022/MEM/stat/results.json
# Data saved to 2023/MEM/stat/results.json
# Data saved to 2024/MEM/stat/results.json
# Data saved to 2021/ART/stat/results.json
# Data saved to 2022/ART/stat/results.json
# Data saved to 2023/ART/stat/results.json
# Data saved to 2024/ART/stat/results.json
# Data saved to 2021/REPORT/stat/results.json
# Data saved to 2022/REPORT/stat/results.json
# Data saved to 2023/REPORT/stat/results.json
# Data saved to 2024/REPORT/stat/results.json
# Data saved to 2021/COMM/stat/results.json
# Data saved to 2022/COMM/stat/results.json
# Data saved to 2023/COMM/stat/results.json
# Data saved to 2024/COMM/stat/results.json
# Data saved to 2021/POSTER/stat/results.json
# Data saved to 2022/POSTER/stat/results.json
# Data saved to 2023/POSTER/stat/results.json
# Data saved to 2024/POSTER/stat/results.json
# Data saved to 2021/OTHER/stat/results.json
# Data saved to 2022/OTHER/stat/results.json
# Data saved to 2023/OTHER/stat/results.json
# Data saved to 2024/OTHER/stat/results.json
# Data saved to 2021/OUV/stat/results.json
# Data saved to 2022/OUV/stat/results.json
# Data saved to 2023/OUV/stat/results.json
# Data saved to 2024/OUV/stat/results.json
